# %%
import requests
import json
from requests import get
from pprint import pprint
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time
from scipy.stats import linregress
from pprint import pprint

from citipy import citipy

output_data_file = "output_data/cities.csv"

# %%
api_key = 'e9e906f03cbc7c59d38cc2e5d4bfcd9a'

#weather = f"http://api.openweathermap.org/data/2.5/weather?q={city}&units=imperial&appid={api_key}"

lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
lat_lngs = []
cities = []

lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 640

# %%
# Create DF to store data

api_key = 'e9e906f03cbc7c59d38cc2e5d4bfcd9a'

weather = f"http://api.openweathermap.org/data/2.5/weather?"


city_list = []
temperature = []
humidity = []
cloudiness = []
wind_speed = []
date = []
country = []
lat = []
long = []

print("Beginning Data Retrieval")
print("-----------------------------")
record = 1

      
for city in cities:
    time.sleep(1.1)
    url = f"{weather}appid={api_key}&q={city}&units=imperial"
    response = requests.get(url)
    data = response.json()
    #pprint(data)
    try:
        name = data["name"]
        city_list.append(name)
        temp = data["main"]["temp_max"]
        temperature.append(temp)
        humid = data["main"]["humidity"]
        humidity.append(humid)
        clouds = data["clouds"]["all"]
        cloudiness.append(clouds)
        wind = data["wind"]["speed"]
        wind_speed.append(wind)
        lati = data["coord"]["lat"]
        lat.append(lati)
        longi = data["coord"]["lon"]
        long.append(longi)
        dt = data["dt"]
        date.append(dt)
        CNT = data["sys"]["country"]
        country.append(CNT)
        print(f"Processing Record {record} | {name}")
        record +=1
    except KeyError: 
        print("City not found")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 | Punta Arenas
# Processing Record 2 | Saint-Philippe
# Processing Record 3 | Cidreira
# Processing Record 4 | Klaksvík
# Processing Record 5 | Darhan
# Processing Record 6 | Santa Fe
# Processing Record 7 | Ushuaia
# Processing Record 8 | Barcelos
# Processing Record 9 | Neuquén
# Processing Record 10 | Hermanus
# Processing Record 11 | Avarua
# City not found
# Processing Record 12 | Marawi
# Processing Record 13 | Barra do Corda
# Processing Record 14 | Kaitangata
# Processing Record 15 | Pisco
# Processing Record 16 | Chapleau
# Processing Record 17 | Rikitea
# Processing Record 18 | Busselton
# Processing Record 19 | Pangnirtung
# Processing Record 20 | Ponta do Sol
# Processing Record 21 | Mariehamn
# Processing Record 22 | Port Alfred
# Processing Record 23 | Angoche
# Processing Record 24 | Cape Town
# Processing Record 25 | Puerto Ayora
# Processing Record 26 | Nikolskoye
# Processing Record 27 | Batouri
# Processing Record 28 | Leningradskiy
# Processing Record 29 | Castro
# Processing Record 30 | San Jose
# Processing Record 31 | Nanortalik
# Processing Record 32 | Flinders
# Processing Record 33 | Agirish
# Processing Record 34 | Gravdal
# Processing Record 35 | Vaini
# Processing Record 36 | Port Lincoln
# Processing Record 37 | Narsaq
# Processing Record 38 | Estelle
# Processing Record 39 | Diamantino
# Processing Record 40 | Portland
# City not found
# Processing Record 41 | Qaanaaq
# Processing Record 42 | Dauphin
# Processing Record 43 | San Andrés
# Processing Record 44 | Albany
# Processing Record 45 | Cap Malheureux
# Processing Record 46 | Bethel
# City not found
# Processing Record 47 | Chokurdakh
# Processing Record 48 | Kisesa
# Processing Record 49 | College
# Processing Record 50 | Örnsköldsvik
# Processing Record 51 | Nieuwpoort
# Processing Record 52 | Hobart
# Processing Record 53 | Bulgan
# Processing Record 54 | Namatanai
# Processing Record 55 | Bredasdorp
# Processing Record 56 | Arraial do Cabo
# Processing Record 57 | New Norfolk
# Processing Record 58 | Atar
# Processing Record 59 | Atuona
# Processing Record 60 | Kroya
# City not found
# Processing Record 61 | Dondaicha
# Processing Record 62 | Lebu
# Processing Record 63 | Provideniya
# City not found
# Processing Record 64 | Hithadhoo
# Processing Record 65 | Severo-Kuril'sk
# Processing Record 66 | Breves
# Processing Record 67 | Tuktoyaktuk
# Processing Record 68 | Bluff
# Processing Record 69 | Dikson
# Processing Record 70 | Barrow
# Processing Record 71 | Hasaki
# Processing Record 72 | Auki
# Processing Record 73 | Port Elizabeth
# Processing Record 74 | Myanaung
# Processing Record 75 | Ubinskoye
# City not found
# Processing Record 76 | Kapaa
# City not found
# Processing Record 77 | Ørnes
# City not found
# Processing Record 78 | Pevek
# Processing Record 79 | Vysokogornyy
# Processing Record 80 | Sibut
# City not found
# Processing Record 81 | Sørland
# Processing Record 82 | Cherskiy
# Processing Record 83 | Luján
# City not found
# Processing Record 84 | Namtsy
# Processing Record 85 | Iqaluit
# Processing Record 86 | Mataura
# Processing Record 87 | Tasiilaq
# Processing Record 88 | Manjacaze
# Processing Record 89 | La Ronge
# Processing Record 90 | Kapoeta
# Processing Record 91 | Alofi
# Processing Record 92 | Khorol
# Processing Record 93 | Jamestown
# Processing Record 94 | George Town
# Processing Record 95 | Katangli
# Processing Record 96 | Husavik
# Processing Record 97 | Torbay
# Processing Record 98 | Makkah al Mukarramah
# Processing Record 99 | Saint Paul Harbor
# Processing Record 100 | Mossamedes
# Processing Record 101 | Yellowknife
# Processing Record 102 | Vardø
# Processing Record 103 | Indiana
# Processing Record 104 | Takoradze
# Processing Record 105 | Puerto Ayacucho
# Processing Record 106 | Ambilobe
# Processing Record 107 | Batemans Bay
# Processing Record 108 | Areosa
# City not found
# Processing Record 109 | Aksarka
# Processing Record 110 | Sørkjosen
# Processing Record 111 | Esperance
# Processing Record 112 | Hilo
# Processing Record 113 | Port Keats
# Processing Record 114 | Paita
# Processing Record 115 | Hamilton
# Processing Record 116 | Los Llanos de Aridane
# City not found
# Processing Record 117 | Thompson
# Processing Record 118 | Najrān
# Processing Record 119 | Faanui
# Processing Record 120 | Turukhansk
# Processing Record 121 | Linkuva
# Processing Record 122 | Saskylakh
# Processing Record 123 | Nelson Bay
# Processing Record 124 | Grindavik
# Processing Record 125 | Souillac
# Processing Record 126 | Longyearbyen
# Processing Record 127 | Mount Gambier
# Processing Record 128 | Vestmanna
# Processing Record 129 | Lerwick
# City not found
# Processing Record 130 | Vanavara
# Processing Record 131 | Abonnema
# Processing Record 132 | Salalah
# Processing Record 133 | Verkhnyaya Inta
# Processing Record 134 | Ruwi
# Processing Record 135 | Rūjiena
# Processing Record 136 | Moerai
# Processing Record 137 | Synya
# Processing Record 138 | Maniwaki
# Processing Record 139 | Airai
# Processing Record 140 | East London
# Processing Record 141 | Port Blair
# Processing Record 142 | São Miguel do Araguaia
# Processing Record 143 | Xichang
# Processing Record 144 | Butaritari
# Processing Record 145 | Teya
# Processing Record 146 | Kruisfontein
# Processing Record 147 | Kondinskoye
# City not found
# City not found
# Processing Record 148 | Ponta Delgada
# Processing Record 149 | Brus Laguna
# Processing Record 150 | Chodavaram
# Processing Record 151 | Opuwo
# Processing Record 152 | Nioro
# Processing Record 153 | Praia da Vitória
# Processing Record 154 | Durusu
# Processing Record 155 | Dingle
# City not found
# Processing Record 156 | Chamba
# Processing Record 157 | Kavieng
# Processing Record 158 | Ngunguru
# Processing Record 159 | Kloulklubed
# Processing Record 160 | Verkhovazh'ye
# Processing Record 161 | Bilibino
# Processing Record 162 | Kiryat Gat
# Processing Record 163 | Saint George
# Processing Record 164 | San Patricio
# Processing Record 165 | Lavrentiya
# Processing Record 166 | Tsumeb
# Processing Record 167 | Lüderitz
# City not found
# Processing Record 168 | Bayanday
# Processing Record 169 | Tutóia
# Processing Record 170 | Safi
# Processing Record 171 | Road Town
# Processing Record 172 | Amapá
# Processing Record 173 | Mayo
# City not found
# Processing Record 174 | Hong Kong
# Processing Record 175 | Quesnel
# Processing Record 176 | Kasongo-Lunda
# Processing Record 177 | Tuatapere
# Processing Record 178 | Laas
# Processing Record 179 | Poltava
# Processing Record 180 | Bengkulu
# Processing Record 181 | Upernavik
# Processing Record 182 | Bilma
# City not found
# Processing Record 183 | Ilulissat
# Processing Record 184 | Umm Kaddadah
# City not found
# Processing Record 185 | Kosh-Agach
# Processing Record 186 | Cayenne
# Processing Record 187 | Pionerskiy
# Processing Record 188 | Zorritos
# Processing Record 189 | Rabo de Peixe
# Processing Record 190 | Yamada
# Processing Record 191 | Riverton
# Processing Record 192 | Hofn
# Processing Record 193 | Cabo San Lucas
# Processing Record 194 | Thinadhoo
# Processing Record 195 | Sabang
# Processing Record 196 | Tura
# Processing Record 197 | Conway
# Processing Record 198 | Katsuura
# City not found
# Processing Record 199 | Nālūt
# Processing Record 200 | São José da Coroa Grande
# Processing Record 201 | Saint Anthony
# Processing Record 202 | Goderich
# Processing Record 203 | Hefei
# Processing Record 204 | Charters Towers
# Processing Record 205 | Maumere
# Processing Record 206 | Hvide Sande
# Processing Record 207 | Adjumani
# Processing Record 208 | Širvintos
# Processing Record 209 | São João da Barra
# Processing Record 210 | Bairiki Village
# Processing Record 211 | Byron Bay
# Processing Record 212 | Ossora
# Processing Record 213 | Tilichiki
# Processing Record 214 | Dumas
# Processing Record 215 | Dourbali
# Processing Record 216 | Prince Rupert
# Processing Record 217 | Katsina
# Processing Record 218 | Ust'-Ilimsk
# Processing Record 219 | Chui
# Processing Record 220 | Hobyo
# Processing Record 221 | Sault Ste. Marie
# Processing Record 222 | Oranjemund
# City not found
# Processing Record 223 | Adrar
# Processing Record 224 | Moanda
# Processing Record 225 | Evensk
# Processing Record 226 | Bonthe
# Processing Record 227 | Latung
# Processing Record 228 | Khatanga
# Processing Record 229 | Russkiy Kameshkir
# City not found
# Processing Record 230 | Amuntai
# Processing Record 231 | Guerrero Negro
# Processing Record 232 | Mandalgovi
# Processing Record 233 | Esmeraldas
# Processing Record 234 | Igrim
# Processing Record 235 | Salinas
# Processing Record 236 | Heyang
# Processing Record 237 | Panalingaan
# Processing Record 238 | Hakkâri Province
# Processing Record 239 | Waingapu
# Processing Record 240 | Ketchikan
# Processing Record 241 | Aklavik
# Processing Record 242 | Saint-Augustin
# Processing Record 243 | Clyde River
# Processing Record 244 | Camopi
# Processing Record 245 | Mombetsu
# Processing Record 246 | Berdigestyakh
# Processing Record 247 | Mahébourg
# Processing Record 248 | Lashio
# Processing Record 249 | Sur
# Processing Record 250 | Wakkanai
# Processing Record 251 | Igunga
# Processing Record 252 | Sibolga
# Processing Record 253 | Kangaatsiaq
# Processing Record 254 | Champerico
# Processing Record 255 | Straumen
# Processing Record 256 | Atbasar
# Processing Record 257 | Narrabri
# Processing Record 258 | Bitung
# Processing Record 259 | São Filipe
# Processing Record 260 | Gouyave
# Processing Record 261 | Lufilufi
# Processing Record 262 | Tateyama
# Processing Record 263 | Aswān
# City not found
# Processing Record 264 | Rawson
# Processing Record 265 | Srednekolymsk
# Processing Record 266 | Jumla
# Processing Record 267 | Nouadhibou
# Processing Record 268 | Departamento de Maldonado
# Processing Record 269 | Quatre Cocos
# Processing Record 270 | Hambantota
# Processing Record 271 | Baker City
# Processing Record 272 | Along
# Processing Record 273 | Tomatlán
# Processing Record 274 | Caarapó
# Processing Record 275 | Kiruna
# Processing Record 276 | Talara
# Processing Record 277 | San Cristobal
# Processing Record 278 | Karratha
# Processing Record 279 | Chokwé
# Processing Record 280 | Bandarbeyla
# Processing Record 281 | Atherton
# City not found
# Processing Record 282 | Bărăști
# Processing Record 283 | Kindu
# Processing Record 284 | Eluru
# Processing Record 285 | Bud
# City not found
# Processing Record 286 | Arlit
# Processing Record 287 | Acaraú
# Processing Record 288 | Dutlwe
# Processing Record 289 | Geraldton
# Processing Record 290 | Talcahuano
# Processing Record 291 | Brownwood
# Processing Record 292 | Carnarvon
# Processing Record 293 | Ciudad del Carmen
# Processing Record 294 | Isangel
# Processing Record 295 | Coquimbo
# Processing Record 296 | Alta
# Processing Record 297 | Vostochnyy
# City not found
# Processing Record 298 | Pitimbu
# Processing Record 299 | Nishihara
# Processing Record 300 | Vila Franca do Campo
# Processing Record 301 | West Wendover
# Processing Record 302 | Mar del Plata
# City not found
# Processing Record 303 | Codrington
# Processing Record 304 | Lorengau
# Processing Record 305 | Fort Nelson
# Processing Record 306 | Ilo
# Processing Record 307 | Aspros
# Processing Record 308 | Kaeo
# Processing Record 309 | Fasa
# Processing Record 310 | Northam
# Processing Record 311 | Gilgit
# Processing Record 312 | Buchanan
# Processing Record 313 | Shenjiamen
# Processing Record 314 | Makakilo City
# Processing Record 315 | Ancud
# Processing Record 316 | Altamont
# Processing Record 317 | Ust'-Ishim
# Processing Record 318 | Wewak
# Processing Record 319 | Prestea
# Processing Record 320 | Ippy
# Processing Record 321 | Caucayá
# Processing Record 322 | Verkhoyansk
# Processing Record 323 | Mechernich
# Processing Record 324 | Yumen
# Processing Record 325 | Turbat
# Processing Record 326 | Phillipsburg
# Processing Record 327 | Severnyy
# City not found
# Processing Record 328 | Asău
# Processing Record 329 | Sémbé
# Processing Record 330 | Khandyga
# Processing Record 331 | Lagoa
# Processing Record 332 | Ziro
# Processing Record 333 | Carauari
# Processing Record 334 | Chebenki
# Processing Record 335 | Oranjestad
# Processing Record 336 | Bubaque
# Processing Record 337 | Puerto Baquerizo Moreno
# Processing Record 338 | Tual
# Processing Record 339 | Norman Wells
# Processing Record 340 | Sayansk
# Processing Record 341 | San Felipe
# Processing Record 342 | Los Reyes Acaquilpan
# Processing Record 343 | São João de Pirabas
# Processing Record 344 | Bambous Virieux
# Processing Record 345 | Khangarh
# Processing Record 346 | Manta
# Processing Record 347 | Korla
# Processing Record 348 | Przhevalskoye
# Processing Record 349 | Hernani
# Processing Record 350 | San Pedro Buenavista
# Processing Record 351 | Polunochnoye
# Processing Record 352 | Morón
# Processing Record 353 | Sechura
# Processing Record 354 | Periam
# Processing Record 355 | Bousso
# Processing Record 356 | Boa Vista
# Processing Record 357 | Beringovskiy
# Processing Record 358 | Birin
# Processing Record 359 | Batagay-Alyta
# Processing Record 360 | Ulladulla
# Processing Record 361 | Hudson Bay
# Processing Record 362 | Ahipara
# Processing Record 363 | Sambava
# Processing Record 364 | Teguise
# Processing Record 365 | Kalmunai
# Processing Record 366 | Dingzhou
# Processing Record 367 | Brae
# Processing Record 368 | Tiksi
# Processing Record 369 | Jalor
# Processing Record 370 | Port Hedland
# Processing Record 371 | Naze
# Processing Record 372 | Cruz Grande
# Processing Record 373 | Kimbe
# Processing Record 374 | Marathon
# Processing Record 375 | Bonavista
# Processing Record 376 | Arrondissement de La Rochelle
# Processing Record 377 | Praia
# Processing Record 378 | Bambanglipuro
# Processing Record 379 | Nuevo Progreso
# Processing Record 380 | Talnakh
# Processing Record 381 | Saldanha
# Processing Record 382 | Veinticinco de Mayo
# City not found
# Processing Record 383 | Ribeira Grande
# Processing Record 384 | Stuttgart
# Processing Record 385 | Cruz do Espírito Santo
# Processing Record 386 | Kysyl-Syr
# Processing Record 387 | Presidencia Roque Sáenz Peña
# Processing Record 388 | Ceres
# Processing Record 389 | Mažeikiai
# Processing Record 390 | Tacoronte
# Processing Record 391 | Hals
# Processing Record 392 | Tibagi
# Processing Record 393 | Chapada dos Guimarães
# Processing Record 394 | Dombarovskiy
# Processing Record 395 | Mananara
# City not found
# Processing Record 396 | La Tuque
# Processing Record 397 | Gunjur
# Processing Record 398 | Harindānga
# Processing Record 399 | Leer
# Processing Record 400 | Oskemen
# Processing Record 401 | Jalu
# Processing Record 402 | Baruun-Urt
# Processing Record 403 | Vao
# Processing Record 404 | Manacapuru
# Processing Record 405 | Laguna
# City not found
# City not found
# Processing Record 406 | Ladário
# City not found
# Processing Record 407 | Lao Cai
# Processing Record 408 | Vostok
# Processing Record 409 | Urucará
# Processing Record 410 | Nouakchott
# Processing Record 411 | Chauk
# Processing Record 412 | Lumphat
# Processing Record 413 | Ternate
# Processing Record 414 | Sorochinsk
# Processing Record 415 | Ndioum
# Processing Record 416 | Edd
# Processing Record 417 | Marabu
# Processing Record 418 | Celestún
# Processing Record 419 | Muskogee
# Processing Record 420 | Sucúa
# Processing Record 421 | Gigmoto
# Processing Record 422 | Yangi Marg`ilon
# Processing Record 423 | Port Pirie
# Processing Record 424 | Pleshanovo
# Processing Record 425 | Kautokeino
# Processing Record 426 | Thaba-Tseka
# Processing Record 427 | Jämsä
# Processing Record 428 | Khakhea
# Processing Record 429 | Polyarny
# Processing Record 430 | Omboué
# Processing Record 431 | Uyskoye
# Processing Record 432 | Mogadishu
# Processing Record 433 | Oodweyne
# Processing Record 434 | Muriwai Beach
# Processing Record 435 | Campbell River
# City not found
# Processing Record 436 | Puerto Escondido
# Processing Record 437 | Awjilah
# City not found
# Processing Record 438 | Jijiga
# Processing Record 439 | San Rafael
# Processing Record 440 | Yershov
# Processing Record 441 | Margate
# Processing Record 442 | Half Moon Bay
# City not found
# City not found
# Processing Record 443 | San Juan
# Processing Record 444 | Ust'-Omchug
# Processing Record 445 | Rumphi
# Processing Record 446 | Petropavl
# Processing Record 447 | Kargopol'
# Processing Record 448 | Touros
# Processing Record 449 | Zacatlán
# Processing Record 450 | Yagoua
# Processing Record 451 | Dothan
# Processing Record 452 | Constitución
# Processing Record 453 | Gondanglegi
# Processing Record 454 | La Palma
# Processing Record 455 | Cehegín
# Processing Record 456 | Rivers
# Processing Record 457 | Spas-Demensk
# Processing Record 458 | Tsimmerbude
# Processing Record 459 | São Félix do Xingu
# Processing Record 460 | Sobolevo
# Processing Record 461 | Shebunino
# City not found
# Processing Record 462 | Lata
# Processing Record 463 | Killarney
# Processing Record 464 | Ol'ga
# Processing Record 465 | Maniitsoq
# Processing Record 466 | Saint-Joseph
# Processing Record 467 | Intipucá
# Processing Record 468 | Saint-Pierre
# City not found
# Processing Record 469 | Pangoa
# Processing Record 470 | Edgewater
# Processing Record 471 | Zhigansk
# Processing Record 472 | Punta Cardon
# Processing Record 473 | Varhaug
# Processing Record 474 | Atocha
# Processing Record 475 | Mudon
# Processing Record 476 | Kungurtug
# Processing Record 477 | Anloga
# Processing Record 478 | Kitimat
# Processing Record 479 | Tautira
# Processing Record 480 | Les Cayes
# Processing Record 481 | Lagunas
# Processing Record 482 | Jardim
# Processing Record 483 | Kostanay
# Processing Record 484 | Loganville
# Processing Record 485 | Siavonga
# City not found
# Processing Record 486 | Okhotsk
# Processing Record 487 | Westport
# Processing Record 488 | Puerto Madryn
# Processing Record 489 | La Rioja
# City not found
# Processing Record 490 | Maceió
# Processing Record 491 | Plettenberg Bay
# Processing Record 492 | Kununurra
# Processing Record 493 | Yulara
# Processing Record 494 | Bereda
# Processing Record 495 | Guadalupe
# Processing Record 496 | Ust'-Koksa
# Processing Record 497 | Fairbanks
# Processing Record 498 | Usinsk
# Processing Record 499 | Uribia
# Processing Record 500 | Karasuk
# Processing Record 501 | San Quintín
# Processing Record 502 | Tommot
# Processing Record 503 | Boyolangu
# Processing Record 504 | Paamiut
# Processing Record 505 | Río Gallegos
# Processing Record 506 | Valley City
# Processing Record 507 | Novy Urengoy
# Processing Record 508 | Nsanje
# Processing Record 509 | Gmina Strzelin
# City not found
# Processing Record 510 | Philadelphia
# Processing Record 511 | Te Anau
# Processing Record 512 | Mackay
# Processing Record 513 | Mehamn
# Processing Record 514 | Taltal
# Processing Record 515 | Kisanga
# Processing Record 516 | Puro
# Processing Record 517 | Redmond
# Processing Record 518 | Whitehorse
# Processing Record 519 | Kieta
# Processing Record 520 | Doka
# Processing Record 521 | Chirongui
# Processing Record 522 | Lavra
# Processing Record 523 | Namangan
# Processing Record 524 | Tiarei
# Processing Record 525 | Paysandu
# Processing Record 526 | Bang Khla
# Processing Record 527 | Hopfgarten
# Processing Record 528 | Fortuna
# Processing Record 529 | Lahān
# City not found
# Processing Record 530 | Udachny
# Processing Record 531 | Padang
# Processing Record 532 | Comodoro Rivadavia
# Processing Record 533 | Calituban
# Processing Record 534 | Nemuro
# Processing Record 535 | Biloela
# Processing Record 536 | Uva
# City not found
# Processing Record 537 | Arrondissement de Limoux
# Processing Record 538 | Tigil'
# City not found
# Processing Record 539 | Yar-Sale
# City not found
# Processing Record 540 | El Retorno
# Processing Record 541 | Birao
# City not found
# Processing Record 542 | Loa Janan
# Processing Record 543 | Stary Oskol
# Processing Record 544 | Chitungwiza
# Processing Record 545 | Ulaanbaatar
# Processing Record 546 | Broome
# Processing Record 547 | Bozoum
# Processing Record 548 | Pak Chong
# City not found
# Processing Record 549 | Sinop Province
# Processing Record 550 | Nueva Loja
# Processing Record 551 | Grand-Santi
# Processing Record 552 | Oktyabr'skiy
# Processing Record 553 | Gizo Government Station
# Processing Record 554 | Iquitos
# Processing Record 555 | Meulaboh
# Processing Record 556 | Nikel
# Processing Record 557 | Tamale
# Processing Record 558 | Rapid City
# Processing Record 559 | Şırnak
# Processing Record 560 | Ouésso
# City not found
# Processing Record 561 | Liverpool
# City not found
# Processing Record 562 | Villanueva
# City not found
# Processing Record 563 | Kakonko
# City not found
# Processing Record 564 | Salinópolis
# Processing Record 565 | São José dos Pinhais
# Processing Record 566 | Troitsko-Pechorsk
# City not found
# Processing Record 567 | Necochea
# City not found
# Processing Record 568 | Mocuba
# Processing Record 569 | Zhangye
# Processing Record 570 | Verkhniy Baskunchak
# Processing Record 571 | Lázaro Cárdenas
# Processing Record 572 | Caranavi
# City not found
# Processing Record 573 | Ves'yegonsk
# Processing Record 574 | High Prairie
# Processing Record 575 | Piaçabuçu
# Processing Record 576 | Shitanjing
# City not found
# Processing Record 577 | Poya
# Processing Record 578 | Suntar
# Processing Record 579 | Faya
# Processing Record 580 | Marsh Harbour
# Processing Record 581 | Gannan
# City not found
# Processing Record 582 | Caucaia

# %%
city_weather = pd.DataFrame({
    
    "City": city_list,
    "Lat": lat,
    "Lng": long,
    "Temperature (F)": temperature,
    "Humidity (%)": humidity,
    "Cloudiness (%)": cloudiness,
    "Wind Speed (mph)": wind_speed,
    "Country": country
    
})

city_weather.head()
# Out:
#              City    Lat     Lng  Temperature (F)  Humidity (%)  \
# 0    Punta Arenas -53.15  -70.92            48.20            61
# 1  Saint-Philippe -21.36   55.77            73.40            73
# 2        Cidreira -30.18  -50.21            70.32            83
# 3        Klaksvík  62.23   -6.59            44.60           100
# 4          Darhan  49.49  105.92            35.74            78
#
#    Cloudiness (%)  Wind Speed (mph) Country
# 0              75              8.05      CL
# 1               0              8.05      RE
# 2             100             13.69      BR
# 3               3              8.05      FO
# 4              82              0.94      MN

# %%
city_weather.to_csv(r"/Users/jordanheise/Desktop/homework-repos/city_weather.csv")

# %%
y=city_weather["Temperature (F)"]
#plot chart
plt.scatter(city_weather["Lat"], y, s = 30, color = 'red', edgecolor = 'black', alpha = .75)
# add ref. lines
for i in list(np.arange(-5, 100, 15)):
    plt.axhline(i,linewidth=1, color='grey')
for i in list(np.arange(-60, 80, 20)):
    plt.axvline(i,linewidth=1, color='grey')
    
plt.suptitle('City Latitude vs. Temperature (F)')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
# Out:
# Text(0, 0.5, 'Temperature (F)')

# %%
y=city_weather["Humidity (%)"]
#plot chart
plt.scatter(city_weather["Lat"], y, s = 30, color = 'red', edgecolor = 'black', alpha = .75)
# add ref. lines
for i in list(np.arange(0, 100, 15)):
    plt.axhline(i,linewidth=1, color='grey')
for i in list(np.arange(-60, 80, 20)):
    plt.axvline(i,linewidth=1, color='grey')
    
plt.suptitle('City Latitude vs. Humidity (%)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
# Out:
# Text(0, 0.5, 'Humidity (%)')

# %%
y=city_weather["Cloudiness (%)"]
#plot chart
plt.scatter(city_weather["Lat"], y, s = 30, color = 'red', edgecolor = 'black', alpha = .75)
# add ref. lines
for i in list(np.arange(0, 100, 15)):
    plt.axhline(i,linewidth=1, color='grey')
for i in list(np.arange(-60, 80, 20)):
    plt.axvline(i,linewidth=1, color='grey')
    
plt.suptitle('City Latitude vs. Cloudiness (%)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
# Out:
# Text(0, 0.5, 'Cloudiness (%)')

# %%
y=city_weather["Wind Speed (mph)"]
#plot chart
plt.scatter(city_weather["Lat"], y, s = 30, color = 'red', edgecolor = 'black', alpha = .75)
# add ref. lines
for i in list(np.arange(0, 30, 15)):
    plt.axhline(i,linewidth=1, color='grey')
for i in list(np.arange(-60, 80, 20)):
    plt.axvline(i,linewidth=1, color='grey')
    
plt.suptitle('City Latitude vs. Wind Speed (mph)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
# Out:
# Text(0, 0.5, 'Wind Speed (mph)')

# %%
y=city_weather["Temperature (F)"]
#plot chart
plt.scatter(city_weather["Lat"], y, s = 30, color = 'red', edgecolor = 'black', alpha = .75)
# add ref. lines

# m,b = np.polyfit(city_weather["Lat"], y, 1)
# coef = np.polyfit(city_weather["Lat"],y,1)
# poly1d_fn = np.poly1d(coef)
# # plt.plot(city_weather["Lat"],y, 'yo', city_weather["Lat"], poly1d_fn(city_weather["Lat"]), '--k')
# linregress(city_weather["Lat"],y)

for i in list(np.arange(-5, 100, 15)):
    plt.axhline(i,linewidth=1, color='grey')
for i in list(np.arange(-60, 80, 20)):
    plt.axvline(i,linewidth=1, color='grey')
    plt.xlim(left=0)
    
plt.suptitle('Northern Hemisphere - City Latitude vs. Temperature (F)')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
# Out:
# Text(0, 0.5, 'Temperature (F)')

# %%
y=city_weather["Temperature (F)"]
#plot chart
plt.scatter(city_weather["Lat"], y, s = 30, color = 'red', edgecolor = 'black', alpha = .75)


# add ref. lines
for i in list(np.arange(5, 100, 15)):
    plt.axhline(i,linewidth=1, color='grey')
for i in list(np.arange(-60, 80, 20)):
    plt.axvline(i,linewidth=1, color='grey')
    plt.xlim(right=0)
    plt.ylim(bottom=35)
    
plt.suptitle('Southern Hemisphere - City Latitude vs. Temperature (F)')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
# Out:
# Text(0, 0.5, 'Temperature (F)')

# %%
y=city_weather["Humidity (%)"]
#plot chart
plt.scatter(city_weather["Lat"], y, s = 30, color = 'red', edgecolor = 'black', alpha = .75)
# add ref. lines
for i in list(np.arange(0, 100, 15)):
    plt.axhline(i,linewidth=1, color='grey')
for i in list(np.arange(-60, 80, 20)):
    plt.axvline(i,linewidth=1, color='grey')
    plt.xlim(left=0)
    
plt.suptitle('Northern Hemisphere - City Latitude vs. Humidity (%)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
# Out:
# Text(0, 0.5, 'Humidity (%)')

# %%
y=city_weather["Humidity (%)"]
#plot chart
plt.scatter(city_weather["Lat"], y, s = 30, color = 'red', edgecolor = 'black', alpha = .75)
# add ref. lines
for i in list(np.arange(0, 100, 15)):
    plt.axhline(i,linewidth=1, color='grey')
for i in list(np.arange(-60, 80, 20)):
    plt.axvline(i,linewidth=1, color='grey')
    plt.xlim(right=0)
    
plt.suptitle('Southern Hemisphere - City Latitude vs. Humidity (%)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
# Out:
# Text(0, 0.5, 'Humidity (%)')

# %%
y=city_weather["Cloudiness (%)"]
#plot chart
plt.scatter(city_weather["Lat"], y, s = 30, color = 'red', edgecolor = 'black', alpha = .75)
# add ref. lines
for i in list(np.arange(0, 100, 15)):
    plt.axhline(i,linewidth=1, color='grey')
for i in list(np.arange(-60, 80, 20)):
    plt.axvline(i,linewidth=1, color='grey')
    plt.xlim(left=0)
    
plt.suptitle('Northern Hemisphere - City Latitude vs. Cloudiness (%)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
# Out:
# Text(0, 0.5, 'Cloudiness (%)')

# %%
y=city_weather["Cloudiness (%)"]
#plot chart
plt.scatter(city_weather["Lat"], y, s = 30, color = 'red', edgecolor = 'black', alpha = .75)
# add ref. lines
for i in list(np.arange(0, 100, 15)):
    plt.axhline(i,linewidth=1, color='grey')
for i in list(np.arange(-60, 80, 20)):
    plt.axvline(i,linewidth=1, color='grey')
    plt.xlim(right=0)
    
plt.suptitle('Southern Hemisphere - City Latitude vs. Cloudiness (%)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
# Out:
# Text(0, 0.5, 'Cloudiness (%)')

# %%
y=city_weather["Wind Speed (mph)"]
#plot chart
plt.scatter(city_weather["Lat"], y, s = 30, color = 'red', edgecolor = 'black', alpha = .75)
# add ref. lines
for i in list(np.arange(0, 30, 10)):
    plt.axhline(i,linewidth=1, color='grey')
for i in list(np.arange(-60, 80, 20)):
    plt.axvline(i,linewidth=1, color='grey')
    plt.xlim(left=0)
    
plt.suptitle('Northern Hemisphere - City Latitude vs. Wind Speed (mph)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
# Out:
# Text(0, 0.5, 'Wind Speed (mph)')

# %%
y=city_weather["Wind Speed (mph)"]
#plot chart
plt.scatter(city_weather["Lat"], y, s = 30, color = 'red', edgecolor = 'black', alpha = .75)
# add ref. lines
for i in list(np.arange(0, 30, 15)):
    plt.axhline(i,linewidth=1, color='grey')
for i in list(np.arange(-60, 80, 20)):
    plt.axvline(i,linewidth=1, color='grey')
    plt.xlim(right=0)
    
plt.suptitle('Southern Hemisphere - City Latitude vs. Wind Speed (mph)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
# Out:
# Text(0, 0.5, 'Wind Speed (mph)')
